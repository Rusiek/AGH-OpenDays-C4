# %%
import json
cache = None
# with open('/home/rusiek/Studia/checkers/server/cache/data.json', 'r') as f:
#     cache = f.read()
#     print(cache)
#     new_cache = ''
#     for i in range(len(cache)):
#         if cache[i] == "'":
#             new_cache += '"'
#         else:
#             new_cache += cache[i]

# with open('/home/rusiek/Studia/checkers/server/cache/data.json', 'w') as f:
#     f.write(new_cache)

# with open('/home/rusiek/Studia/checkers/server/cache/data.json', 'r') as f:
#     cache = f.read()
#     print(cache)
#     print(type(cache))


# with open('/home/rusiek/Studia/checkers/server/cache/data.json', 'w') as f:
#     json.dump(cache, f, indent=4)
# Out:
# {"000001000000000000000000000000000000000000": [0.04846908508792479, 0.04846908508792479, 0.35814030697009336, 0.35814030697009336, 0.1317525446128042, 0.04846908508792479, 0.0065595861832347955], "000000000001000000000000000000000000000000": [0.026596205809893032, 0.19652059236760586, 0.19652059236760586, 0.5341979958210157, 0.026596205809893032, 0.009784203911993257, 0.009784203911993257], "000000000000000001000000000000000000000000": [0.002662442406344998, 0.14536403883764032, 0.39514015949158093, 0.05347647734510069, 0.39514015949158093, 0.007237263944319481, 0.0009794584834325374], "000000000000000000000001000000000000000000": [0.002051665143940554, 0.041208712845093136, 0.3044930813406442, 0.3044930813406442, 0.3044930813406442, 0.041208712845093136, 0.002051665143940554], "000000000000000000000000000001000000000000": [0.0009794584834325374, 0.007237263944319481, 0.39514015949158093, 0.05347647734510069, 0.39514015949158093, 0.14536403883764032, 0.002662442406344998], "00000000
# ...

# %%
data = {}
with open('/home/rusiek/Studia/checkers/server/cache/data.json', 'r') as f:
    cache = json.load(f)
    print(cache)
    key = ''
    value = ''
    curr = 'key'
    for c in cache[2:-2]:
        if curr == 'key' and c == '"':
            curr = 'key_2_val'
        elif curr == 'key':
            key += c
        elif curr == 'key_2_val' and c == '[':
            curr = 'val'
            value += c
        elif curr == 'val' and c == ']':
            curr = 'val_2_key'
            value += c
            data[key] = value
            key = ''
            value = ''
        elif curr == 'val':
            value += c
        elif curr == 'val_2_key' and c == '"':
            curr = 'key'
            
    print(type(cache))
# Out:
# {"000001000000000000000000000000000000000000": [0.04846908508792479, 0.04846908508792479, 0.35814030697009336, 0.35814030697009336, 0.1317525446128042, 0.04846908508792479, 0.0065595861832347955], "000000000001000000000000000000000000000000": [0.026596205809893032, 0.19652059236760586, 0.19652059236760586, 0.5341979958210157, 0.026596205809893032, 0.009784203911993257, 0.009784203911993257], "000000000000000001000000000000000000000000": [0.002662442406344998, 0.14536403883764032, 0.39514015949158093, 0.05347647734510069, 0.39514015949158093, 0.007237263944319481, 0.0009794584834325374], "000000000000000000000001000000000000000000": [0.002051665143940554, 0.041208712845093136, 0.3044930813406442, 0.3044930813406442, 0.3044930813406442, 0.041208712845093136, 0.002051665143940554], "000000000000000000000000000001000000000000": [0.0009794584834325374, 0.007237263944319481, 0.39514015949158093, 0.05347647734510069, 0.39514015949158093, 0.14536403883764032, 0.002662442406344998], "00000000
# ...

# %%
print(data)
cache = {}
for key, value in data.items():
    cache[key] = list(value[1:-1].split(','))
    print(type(key))
    print(type(cache[key]))

print(cache)
# Out:
# {'000001000000000000000000000000000000000000': '[0.04846908508792479, 0.04846908508792479, 0.35814030697009336, 0.35814030697009336, 0.1317525446128042, 0.04846908508792479, 0.0065595861832347955]', '000000000001000000000000000000000000000000': '[0.026596205809893032, 0.19652059236760586, 0.19652059236760586, 0.5341979958210157, 0.026596205809893032, 0.009784203911993257, 0.009784203911993257]', '000000000000000001000000000000000000000000': '[0.002662442406344998, 0.14536403883764032, 0.39514015949158093, 0.05347647734510069, 0.39514015949158093, 0.007237263944319481, 0.0009794584834325374]', '000000000000000000000001000000000000000000': '[0.002051665143940554, 0.041208712845093136, 0.3044930813406442, 0.3044930813406442, 0.3044930813406442, 0.041208712845093136, 0.002051665143940554]', '000000000000000000000000000001000000000000': '[0.0009794584834325374, 0.007237263944319481, 0.39514015949158093, 0.05347647734510069, 0.39514015949158093, 0.14536403883764032, 0.002662442406344998]',
# ...
